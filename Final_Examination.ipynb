# %% [markdown]
# ## Jacky Bruce G. Ibarra
# ## Numerical Method

# %% [markdown]
# #Problem 1
#
#  Use Newton's Forward  (15 points) and Backward  (15 points) formula to find the interpolating polynomial of degree which interpolates the following pairs. After this, find the value of the polynomial at x = 0.50 (10 points)

# %% [markdown]
# ![281297614_379800230772951_950511890051871224_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Problem 2
#
# A function is given according to the table below. Find the derivative for x = 0.70 (30 points)

# %% [markdown]
# ![282185182_527762002321929_7586892450140954548_n.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Problem 3
#
# Create a Python program that integrates the function f(x) = ex  from x1=-1 to x2 = 1 as the interval. Save your program to your repository and send your GitHub link here. (30 points)

# %%
from math import e
def f(x): return e*(x)

a=-1
b=1
h= (b-a)
S=h*(f(a)+f(b))
for i in range (1):
    S = S+f(a+i*h)
Integral=h*S
print('Integral = %f' %Integral)
# Out:
# Integral = -5.436564
