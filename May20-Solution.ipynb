# %% [markdown]
# <a href="https://colab.research.google.com/github/JackyBruceIbarra/Numerical-Methods/blob/main/May20-Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##May20-Solution

# %% [markdown]
# ![received_551456426496136.jpeg](data:image/jpeg;base64,...)
